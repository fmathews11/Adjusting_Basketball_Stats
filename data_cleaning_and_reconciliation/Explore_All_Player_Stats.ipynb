# %%
import pandas as pd
import json
with open('json_files/teams_and_players_2023-12-15.json','r') as f:
    master_json = json.load(f)
pd.DataFrame(master_json["PURDUE"]['player_totals'])
# Out:
#       Rk             Player   G    GS    MP   FG  FGA    FG%   2P  2PA  ...  \
# 0    1.0          Zach Edey  10  10.0   292   80  127  0.630   80  127  ...
# 1    2.0       Braden Smith  10  10.0   319   50  104  0.481   35   71  ...
# 2    3.0        Lance Jones  10  10.0   262   37   87  0.425   19   36  ...
# 3    4.0     Fletcher Loyer  10  10.0   259   30   79  0.380   15   37  ...
# 4    5.0  Trey Kaufman-Renn  10  10.0   159   22   45  0.489   18   36  ...
# 5    6.0       Mason Gillis  10   0.0   180   16   31  0.516    6   12  ...
# 6    7.0       Myles Colvin  10   0.0   111   17   37  0.459    5   11  ...
# 7    8.0       Camden Heide  10   0.0   124   13   23  0.565    8   14  ...
# 8    9.0        Caleb Furst  10   0.0   144   10   26  0.385    8   19  ...
# 9   10.0          Will Berg   4   0.0    20    8   11  0.727    8   11  ...
# 10  11.0       Ethan Morton   9   0.0   113    2   10  0.200    0    2  ...
# 11  12.0      Brian Waddell   4   0.0    25    3    6  0.500    3    4  ...
# 12  13.0           Sam King   2   0.0     2    0    0    NaN    0    0  ...
# 13  14.0       Chase Martin   3   0.0     7    1    3  0.333    1    2  ...
# 14  15.0     Carson Barrett   3   0.0     7    0    0    NaN    0    0  ...
# 15  16.0         Josh Furst   1   0.0     1    0    0    NaN    0    0  ...
# 16  17.0          Jace Rayl   1   0.0     1    0    0    NaN    0    0  ...
# 17   NaN      School Totals  10   NaN  2025  289  589  0.491  206  382  ...
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS    team
# 0    44   64  108   12    1   26   17   18  248  PURDUE
# 1     6   53   59   72   16    1   25   17  132  PURDUE
# 2     3   23   26   22   17    1   17   19  106  PURDUE
# 3     4   23   27   13    8    0   14   15  102  PURDUE
# 4    12   25   37   11    2    3    7   12   65  PURDUE
# 5    11   23   34   13    0    0   11   12   53  PURDUE
# 6     1    5    6    3    3    2    5   10   49  PURDUE
# 7     3   18   21    6    0    6    7   20   34  PURDUE
# 8    10   31   41    7    3    4    8   12   31  PURDUE
# 9     5    4    9    0    0    0    2    4   18  PURDUE
# 10    1    6    7   17    5    2    2    6    8  PURDUE
# 11    1    4    5    2    0    0    0    0    6  PURDUE
# 12    1    2    3    0    0    2    1    0    2  PURDUE
# 13    0    2    2    2    0    0    2    1    2  PURDUE
# 14    0    3    3    0    0    0    0    3    0  PURDUE
# 15    0    1    1    0    0    0    0    0    0  PURDUE
# 16    0    0    0    0    0    0    0    0    0  PURDUE
# 17  115  305  420  180   55   47  122  149  856  PURDUE
#
# [18 rows x 27 columns]

# %%
def create_all_player_totals_dataframe() -> pd.DataFrame:
    
    list_to_transform = []
    
    for team,data in master_json.items():
        
        for player_data_row in data['player_totals']:
            list_to_transform.append(player_data_row)
    
    return pd.DataFrame(list_to_transform,index = [i for i in range(len(list_to_transform))])\
        .query("Player != 'School Totals'").drop('Rk',axis = 1)

create_all_player_totals_dataframe().query("team == 'PURDUE'")
# Out:
#                  Player   G    GS   MP  FG  FGA    FG%  2P  2PA    2P%  ...  \
# 3493          Zach Edey  10  10.0  292  80  127  0.630  80  127  0.630  ...
# 3494       Braden Smith  10  10.0  319  50  104  0.481  35   71  0.493  ...
# 3495        Lance Jones  10  10.0  262  37   87  0.425  19   36  0.528  ...
# 3496     Fletcher Loyer  10  10.0  259  30   79  0.380  15   37  0.405  ...
# 3497  Trey Kaufman-Renn  10  10.0  159  22   45  0.489  18   36  0.500  ...
# 3498       Mason Gillis  10   0.0  180  16   31  0.516   6   12  0.500  ...
# 3499       Myles Colvin  10   0.0  111  17   37  0.459   5   11  0.455  ...
# 3500       Camden Heide  10   0.0  124  13   23  0.565   8   14  0.571  ...
# 3501        Caleb Furst  10   0.0  144  10   26  0.385   8   19  0.421  ...
# 3502          Will Berg   4   0.0   20   8   11  0.727   8   11  0.727  ...
# 3503       Ethan Morton   9   0.0  113   2   10  0.200   0    2  0.000  ...
# 3504      Brian Waddell   4   0.0   25   3    6  0.500   3    4  0.750  ...
# 3505           Sam King   2   0.0    2   0    0    NaN   0    0    NaN  ...
# 3506       Chase Martin   3   0.0    7   1    3  0.333   1    2  0.500  ...
# 3507     Carson Barrett   3   0.0    7   0    0    NaN   0    0    NaN  ...
# 3508         Josh Furst   1   0.0    1   0    0    NaN   0    0    NaN  ...
# 3509          Jace Rayl   1   0.0    1   0    0    NaN   0    0    NaN  ...
#
#       ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS    team
# 3493   44   64  108   12    1   26   17  18  248  PURDUE
# 3494    6   53   59   72   16    1   25  17  132  PURDUE
# 3495    3   23   26   22   17    1   17  19  106  PURDUE
# 3496    4   23   27   13    8    0   14  15  102  PURDUE
# 3497   12   25   37   11    2    3    7  12   65  PURDUE
# 3498   11   23   34   13    0    0   11  12   53  PURDUE
# 3499    1    5    6    3    3    2    5  10   49  PURDUE
# 3500    3   18   21    6    0    6    7  20   34  PURDUE
# 3501   10   31   41    7    3    4    8  12   31  PURDUE
# 3502    5    4    9    0    0    0    2   4   18  PURDUE
# 3503    1    6    7   17    5    2    2   6    8  PURDUE
# 3504    1    4    5    2    0    0    0   0    6  PURDUE
# 3505    1    2    3    0    0    2    1   0    2  PURDUE
# 3506    0    2    2    2    0    0    2   1    2  PURDUE
# 3507    0    3    3    0    0    0    0   3    0  PURDUE
# 3508    0    1    1    0    0    0    0   0    0  PURDUE
# 3509    0    0    0    0    0    0    0   0    0  PURDUE
#
# [17 rows x 26 columns]

# %%
import pandas as pd
import numpy as np
df = pd.read_parquet('parquet_files/box_scores_sports_reference_2024.gzip')
df['ft_disparity'] = df.apply(lambda x: np.abs(int(x.fta) - int(x.opp_fta)),axis = 1)
df.loc[df.ft_disparity >= 30]
# Out:
#           date            opp_name        wl score opp_score  fg fga fgpct  \
# 8   2023-12-10      OHIO DOMINICAN         W    97        49  28  61  .459
# 1   2023-11-08            DEFIANCE         W   102        41  37  59  .627
# 0   2023-11-06              FERRUM         W    91        61  27  52  .519
# 7   2023-12-03              TULANE         L    81        89  31  73  .425
# 7   2023-12-01              MERCER         W    80        69  21  40  .525
# 9   2023-12-10        PRAIRIE VIEW         W   107        56  31  51  .608
# 5   2023-11-26    NEW MEXICO STATE  W (1 OT)    90        84  25  56  .446
# 6   2023-12-01             GEORGIA         L    69        80  27  67  .403
# 6   2023-12-06            UC-DAVIS         W    80        68  22  52  .423
# 1   2023-11-08      SUL ROSS STATE         W    84        49  27  64  .422
# 7   2023-11-26          LOUISVILLE  L (1 OT)    84        90  35  60  .583
# 8   2023-12-02        OLD DOMINION         W    81        68  18  43  .419
# 22  2024-01-31              PURDUE  L (1 OT)    96       105  38  66  .576
# 6   2023-12-02        NORTHEASTERN         L    68        81  29  60  .483
# 7   2023-12-10          IOWA STATE         L    56       107  19  57  .333
# 6   2023-11-28      TEXAS SOUTHERN         W    99        67  29  55  .527
# 23  2024-01-31        NORTHWESTERN  W (1 OT)   105        96  33  57  .579
# 3   2023-11-17           WISCONSIN         L    68        78  24  52  .462
# 6   2023-11-28              PURDUE         L    67        99  26  70  .371
# 6   2023-12-03             FORDHAM         W    89        81  26  48  .542
# 6   2023-12-06              NEVADA         L    68        80  24  54  .444
# 7   2023-12-01  JOHNSON UNIVERSITY         W    97        51  28  58  .483
# 3   2023-11-17       ROBERT MORRIS         W    78        68  24  45  .533
#
#     3p 3pa  ... opp_ftpct opp_orb opp_trb opp_ast opp_stl opp_blk opp_tov  \
# 8    9  31  ...      .750       7      31       7       5       1      17
# 1    6  15  ...     1.000       6      17      11       3       4      32
# 0    7  21  ...      .500       9      26      11       8       1      19
# 7   11  32  ...      .762       4      28       8       8       3      13
# 7    8  15  ...      .500       5      23      20       8       1       7
# 9    9  15  ...      .846      10      21      11      14       3      29
# 5    4  20  ...      .529       8      32      17       7       1      13
# 6   10  23  ...      .714       4      34      10       4       5      14
# 6    4  10  ...      .714       8      28      14       6       5      19
# 1    6  19  ...      .600       4      26      10       5       1      18
# 7    5  18  ...      .735      15      35      12       8       1      12
# 8    5  15  ...      .444       2      23      10       6       2      12
# 22  14  27  ...      .630      12      33      23       6       2      10
# 6    6  21  ...      .784       6      32       8       6       5      12
# 7    7  19  ...      .750      12      39      19      16       5      25
# 6   13  25  ...      .667       6      28      12       7       3       8
# 23  10  21  ...      .750       3      22      23       6       2       8
# 3   13  29  ...      .675       8      26       9      11       2       9
# 6    9  30  ...      .700       8      43      19       4       6      10
# 6    5  10  ...      .800      15      34      23       8       5      14
# 6   10  24  ...      .727       9      31      10       5       4      10
# 7   13  33  ...      .500       9      34      10       7       4      23
# 3    3  13  ...      .778       7      25       8       4       2      21
#
#    opp_pf            team_name ft_disparity
# 8      26  BOWLING GREEN STATE           32
# 1      17      CLEVELAND STATE           30
# 0      24        EAST CAROLINA           33
# 7      14              FORDHAM           32
# 7      28              GEORGIA           32
# 9      30           IOWA STATE           35
# 5      40           LOUISVILLE           32
# 6      14               MERCER           32
# 6      32               NEVADA           30
# 1      25     NEW MEXICO STATE           35
# 7      16     NEW MEXICO STATE           32
# 8      31         NORTHEASTERN           42
# 22     15         NORTHWESTERN           38
# 6      17         OLD DOMINION           42
# 7      17         PRAIRIE VIEW           35
# 6      27               PURDUE           31
# 23     30               PURDUE           38
# 3      15        ROBERT MORRIS           31
# 6      12       TEXAS SOUTHERN           31
# 6      30               TULANE           32
# 6      17             UC DAVIS           30
# 7      28        UNC ASHEVILLE           34
# 3      32            WISCONSIN           31
#
# [23 rows x 39 columns]
